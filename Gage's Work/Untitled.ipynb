# %%
import pandas as pd

# %%
# Out:
#         stadium_name  stadium_location  stadium_open  stadium_close  \
# 0   Acrisure Stadium    Pittsburgh, PA        2001.0            NaN
# 1         Alamo Dome   San Antonio, TX           NaN            NaN
# 2  Allegiant Stadium      Paradise, NV        2020.0            NaN
# 3      Allianz Arena   Munich, Germany           NaN            NaN
# 4     Alltel Stadium  Jacksonville, FL           NaN            NaN
#
#   stadium_type                           stadium_address  \
# 0      outdoor  100 Art Rooney Ave, Pittsburgh, PA 15212
# 1       indoor     100 Montana St, San Antonio, TX 78203
# 2       indoor                                       NaN
# 3      outdoor                                       NaN
# 4          NaN                                       NaN
#
#   stadium_weather_station_code stadium_weather_type stadium_capacity  \
# 0                        15212                 cold           65,500
# 1                        78203                 dome            72000
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   stadium_name                  118 non-null    object
#  1   stadium_location              116 non-null    object
#  2   stadium_open                  89 non-null     float64
#  3   stadium_close                 41 non-null     float64
#  4   stadium_type                  107 non-null    object
#  5   stadium_address               101 non-null    object
#  6   stadium_weather_station_code  100 non-null    object
#  7   stadium_weather_type          107 non-null    object
#  8   stadium_capacity              53 non-null     object
#  9   stadium_surface               67 non-null     object
#  10  STATION                       61 non-null     object
#  11  NAME                          61 non-null     object
# ...

# %%
df2 = pd.read_csv("../Resources/nfl_teams.csv", encoding="unicode_escape")
df2
# Out:
#                    team_name team_name_short team_id team_id_pfr  \
# 0          Arizona Cardinals       Cardinals     ARI         CRD
# 1            Atlanta Falcons         Falcons     ATL         ATL
# 2            Baltimore Colts           Colts     IND         CLT
# 3           Baltimore Ravens          Ravens     BAL         RAV
# 4            Boston Patriots        Patriots      NE         NWE
# 5              Buffalo Bills           Bills     BUF         BUF
# 6          Carolina Panthers        Panthers     CAR         CAR
# 7              Chicago Bears           Bears     CHI         CHI
# 8         Cincinnati Bengals         Bengals     CIN         CIN
# 9           Cleveland Browns          Browns     CLE         CLE
# 10            Dallas Cowboys         Cowboys     DAL         DAL
# 11            Denver Broncos         Broncos     DEN         DEN
# 12             Detroit Lions           Lions     DET         DET
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   team_name                44 non-null     object
#  1   team_name_short          44 non-null     object
#  2   team_id                  44 non-null     object
#  3   team_id_pfr              44 non-null     object
#  4   team_conference          44 non-null     object
#  5   team_division            35 non-null     object
#  6   team_conference_pre2002  44 non-null     object
#  7   team_division_pre2002    42 non-null     object
# dtypes: object(8)
# memory usage: 2.9+ KB

# %%
df3 = pd.read_csv("../Resources/spreadspoke_scores.csv", encoding="unicode_escape")
mask = (df3.schedule_season > 1999) & (df3.schedule_season < 2020) & (df3.team_favorite_id == "LAC")
df3 = df3.loc[mask].reset_index(drop=True)
df3.head()
# Out:
#   schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0     9/10/2000             2000             2             False
# 1      9/9/2001             2001             1             False
# 2     9/23/2001             2001             2             False
# 3     9/30/2001             2001             3             False
# 4     10/7/2001             2001             4             False
#
#             team_home  score_home  score_away            team_away  \
# 0  San Diego Chargers        27.0        28.0   New Orleans Saints
# 1  San Diego Chargers        30.0         3.0  Washington Redskins
# 2      Dallas Cowboys        21.0        32.0   San Diego Chargers
# 3  San Diego Chargers        28.0        14.0   Cincinnati Bengals
# 4    Cleveland Browns        20.0        16.0   San Diego Chargers
#
#   team_favorite_id  spread_favorite over_under_line              stadium  \
# 0              LAC             -5.5            35.5     Qualcomm Stadium
# ...

# %%
df = pd.read_csv("../Resources/nfl_stadiums.csv", encoding="unicode_escape")
df
# Out:
#              stadium_name  stadium_location  stadium_open  stadium_close  \
# 0        Acrisure Stadium    Pittsburgh, PA        2001.0            NaN
# 1              Alamo Dome   San Antonio, TX           NaN            NaN
# 2       Allegiant Stadium      Paradise, NV        2020.0            NaN
# 3           Allianz Arena   Munich, Germany           NaN            NaN
# 4          Alltel Stadium  Jacksonville, FL           NaN            NaN
# ..                    ...               ...           ...            ...
# 113  War Memorial Stadium       Buffalo, NY        1960.0         1972.0
# 114       Wembley Stadium        London, UK        2007.0            NaN
# 115         Wrigley Field       Chicago, IL        1920.0         1970.0
# 116             Yale Bowl     New Haven, CT           NaN            NaN
# 117        Yankee Stadium         Bronx, NY           NaN            NaN
#
#     stadium_type                              stadium_address  \
# ...

# %%
df4 = df.loc[df.stadium_name.isin(df3.stadium)].reset_index(drop=True)
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   stadium_name                  68 non-null     object
#  1   stadium_location              68 non-null     object
#  2   stadium_open                  62 non-null     float64
#  3   stadium_close                 24 non-null     float64
#  4   stadium_type                  64 non-null     object
#  5   stadium_address               63 non-null     object
#  6   stadium_weather_station_code  62 non-null     object
#  7   stadium_weather_type          64 non-null     object
#  8   stadium_capacity              40 non-null     object
#  9   stadium_surface               40 non-null     object
#  10  STATION                       45 non-null     object
#  11  NAME                          45 non-null     object
# ...

# %%
df4.stadium_location.value_counts()
# Out:
# London, UK             4
# Minneapolis, MN        4
# Seattle, WA            3
# Jacksonville, FL       3
# Foxborough, MA         2
# Atlanta, GA            2
# Houston, TX            2
# Indianapolis, IN       2
# Nashville, TN          2
# New Orleans, LA        2
# Los Angeles, CA        2
# Philadelphia, PA       2
# Pittsburgh, PA         2
# Miami Gardens, FL      2
# East Rutherford, NJ    2
# Orchard Park, NY       2
# Denver, CO             2
# Cincinnati, OH         2
# Arlington, TX          2
# Pontiac, MI            1
# San Diego, CA          1
# Tampa, FL              1
# Oakland, CA            1
# Toronto, Canada        1
# Chicago, IL            1
# Tempe, AZ              1
# Irving, TX             1
# Baton Rouge, LA        1
# San Antonio, TX        1
# Santa Clara, CA        1
# Champaign, IL          1
# Baltimore, MD          1
# Green Bay, WI          1
# Detroit, MI            1
# Cleveland, OH          1
# Landover, MD           1
# Mexico City, Mexico    1
# ...

# %%
df5 = df4.loc[df4.stadium_location == "London, UK"]
df5
# Out:
#                  stadium_name stadium_location  stadium_open  stadium_close  \
# 61  Tottenham Hotspur Stadium       London, UK           NaN            NaN
# 62          Tottenham Stadium       London, UK           NaN            NaN
# 63         Twickenham Stadium       London, UK        1909.0            NaN
# 67            Wembley Stadium       London, UK        2007.0            NaN
#
#    stadium_type                          stadium_address  \
# 61          NaN                                      NaN
# 62          NaN                                      NaN
# 63      outdoor    200 Whitton Road, TW2 7BA, London, UK
# 67      outdoor  Wembley, London HA9 0WS, United Kingdom
#
#    stadium_weather_station_code stadium_weather_type stadium_capacity  \
# 61                          NaN                  NaN              NaN
# 62                          NaN                  NaN              NaN
# 63                          NaN             moderate              NaN
# ...

# %%
df4.drop(index=62)
df5 = df4.loc[df4.stadium_location == "London, UK"]
df5
# Out:
#                  stadium_name stadium_location  stadium_open  stadium_close  \
# 61  Tottenham Hotspur Stadium       London, UK           NaN            NaN
# 62          Tottenham Stadium       London, UK           NaN            NaN
# 63         Twickenham Stadium       London, UK        1909.0            NaN
# 67            Wembley Stadium       London, UK        2007.0            NaN
#
#    stadium_type                          stadium_address  \
# 61          NaN                                      NaN
# 62          NaN                                      NaN
# 63      outdoor    200 Whitton Road, TW2 7BA, London, UK
# 67      outdoor  Wembley, London HA9 0WS, United Kingdom
#
#    stadium_weather_station_code stadium_weather_type stadium_capacity  \
# 61                          NaN                  NaN              NaN
# 62                          NaN                  NaN              NaN
# 63                          NaN             moderate              NaN
# ...

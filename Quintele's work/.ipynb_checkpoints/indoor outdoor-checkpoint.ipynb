# %%
import pandas as pd
import csv
import numpy as np
import matplotlib.pyplot as plt

# %%
stadium_csv = "C:/Users/19033/OneDrive/Desktop/SMU bootcamp/Github/projects/smu_project1_nfl/Resources/stadiums_clean.csv"
game_csv = "C:/Users/19033/OneDrive/Desktop/SMU bootcamp/Github/projects/smu_project1_nfl/Resources/gamedata_clean.csv"

# %%
stadium_df = pd.read_csv(stadium_csv)
game_df = pd.read_csv(game_csv)

# %%
stadium_df.head()
# Out:
#               stadium_name   stadium_location  stadium_open  stadium_close  \
# 0        Arrowhead Stadium    Kansas City, MO          1972              0
# 1             AT&T Stadium      Arlington, TX          2009              0
# 2  Bank of America Stadium      Charlotte, NC          1996              0
# 3         Candlestick Park  San Francisco, CA          1960           2013
# 4        CenturyLink Field        Seattle, WA          2002              0
#
#   stadium_type stadium_weather_type stadium_surface  LATITUDE  LONGITUDE  \
# 0      outdoor                 cold           Grass   39.0692   -94.4871
# 1  retractable                 dome       FieldTurf   32.7572   -97.0736
# 2      outdoor             moderate           Grass   35.2236   -80.9552
# 3      outdoor             moderate             NaN   37.6197  -122.3647
# 4      outdoor             moderate       FieldTurf   47.6523  -122.4095
#
#    ELEVATION
# 0      264.9
# 1      163.4
# 2      221.9
# 3        2.4
# 4       93.0

# %%
game_df.head()
# Out:
#    schedule_season team_home  score_home  score_away team_away  \
# 0             2000       ATL          36          28        SF
# 1             2000       BUF          16          13       TEN
# 2             2000       CLE           7          27       JAX
# 3             2000       DAL          14          41       PHI
# 4             2000        GB          16          20       NYJ
#
#   team_favorite_id  spread_favorite  over_under_line              stadium
# 0              ATL             -6.5             46.5         Georgia Dome
# 1              BUF             -1.0             40.0        New Era Field
# 2              JAX            -10.5             38.5  FirstEnergy Stadium
# 3              DAL             -6.0             39.5        Texas Stadium
# 4               GB             -2.5             44.0        Lambeau Field

# %%
df = pd.merge(stadium_df, game_df, suffixes=['_l','_r'], left_on='stadium_name', right_on='stadium')
df
# Out:
#            stadium_name  stadium_location  stadium_open  stadium_close  \
# 0     Arrowhead Stadium   Kansas City, MO          1972              0
# 1     Arrowhead Stadium   Kansas City, MO          1972              0
# 2     Arrowhead Stadium   Kansas City, MO          1972              0
# 3     Arrowhead Stadium   Kansas City, MO          1972              0
# 4     Arrowhead Stadium   Kansas City, MO          1972              0
# ...                 ...               ...           ...            ...
# 5056   Veterans Stadium  Philadelphia, PA          1971           2002
# 5057   Veterans Stadium  Philadelphia, PA          1971           2002
# 5058   Veterans Stadium  Philadelphia, PA          1971           2002
# 5059   Veterans Stadium  Philadelphia, PA          1971           2002
# 5060   Veterans Stadium  Philadelphia, PA          1971           2002
#
#      stadium_type stadium_weather_type stadium_surface  LATITUDE  LONGITUDE  \
# 0         outdoor                 cold           Grass  39.06920  -94.48710
# 1         outdoor                 cold           Grass  39.06920  -94.48710
# 2         outdoor                 cold           Grass  39.06920  -94.48710
# 3         outdoor                 cold           Grass  39.06920  -94.48710
# 4         outdoor                 cold           Grass  39.06920  -94.48710
# ...           ...                  ...             ...       ...        ...
# 5056      outdoor                 cold             NaN  39.87327  -75.22678
# 5057      outdoor                 cold             NaN  39.87327  -75.22678
# 5058      outdoor                 cold             NaN  39.87327  -75.22678
# 5059      outdoor                 cold             NaN  39.87327  -75.22678
# 5060      outdoor                 cold             NaN  39.87327  -75.22678
#
#       ELEVATION  schedule_season team_home  score_home  score_away team_away  \
# 0         264.9             2000        KC          14          27       IND
# 1         264.9             2000        KC          42          10       LAC
# 2         264.9             2000        KC          24          17       SEA
# 3         264.9             2000        KC          17          20       LVR
# 4         264.9             2000        KC          54          34       LAR
# ...         ...              ...       ...         ...         ...       ...
# 5056        3.0             2002       PHI          17           3       NYG
# 5057        3.0             2002       PHI          13          35       IND
# 5058        3.0             2002       PHI          38          14       ARI
# 5059        3.0             2002       PHI          10           3       LAR
# 5060        3.0             2002       PHI          34          21       WAS
#
#      team_favorite_id  spread_favorite  over_under_line            stadium
# 0                 IND             -3.5             44.0  Arrowhead Stadium
# 1                  KC             -4.5             35.5  Arrowhead Stadium
# 2                  KC             -4.0             38.5  Arrowhead Stadium
# 3                  KC             -3.0             43.5  Arrowhead Stadium
# 4                 LAR             -7.0             56.0  Arrowhead Stadium
# ...               ...              ...              ...                ...
# 5056              PHI             -7.0             38.5   Veterans Stadium
# 5057              PHI             -9.5             41.5   Veterans Stadium
# 5058              PHI            -12.0             37.5   Veterans Stadium
# 5059              LAR             -2.0             38.0   Veterans Stadium
# 5060              PHI             -7.5             38.0   Veterans Stadium
#
# [5061 rows x 19 columns]

# %%
df1 = df[df['stadium_type'] == 'outdoor']
df2 = df[df['stadium_type'] == 'indoor']
df3 = df[df['stadium_type'] == 'retractable']

# %%
df1 = df1.groupby('stadium_type', as_index='outdoor').mean()
df1
# Out:
#               stadium_open  stadium_close   LATITUDE  LONGITUDE   ELEVATION  \
# stadium_type
# outdoor        1984.882259     233.317688  38.247222 -89.296961  173.196408
#
#               schedule_season  score_home  score_away  spread_favorite  \
# stadium_type
# outdoor           2009.433572   22.791037    20.25484        -5.370326
#
#               over_under_line
# stadium_type
# outdoor             42.503182

# %%
df2 = df2.groupby('stadium_type', as_index='outdoor').mean()
df2
# Out:
#               stadium_open  stadium_close   LATITUDE  LONGITUDE   ELEVATION  \
# stadium_type
# outdoor        1984.882259     233.317688  38.247222 -89.296961  173.196408
#
#               schedule_season  score_home  score_away  spread_favorite  \
# stadium_type
# outdoor           2009.433572   22.791037    20.25484        -5.370326
#
#               over_under_line
# stadium_type
# outdoor             42.503182
